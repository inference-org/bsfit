# %% [markdown]
# # Fit standard Bayesian model

# %% [markdown]
# author: steeve laquitaine

# %%
# go to project's root path
import os
os.chdir("..")

# %%
# fit the model
# %run main.py
# Out:
# -logl: 2382.091915787947, aic: 4780.183831575894,
#                              k_llh: [1. 1.],
#                              k_prior: [1. 1.],
#                              k_card: [1.],
#                              pr_tail: 0.0,
#                              p_rnd: 0.0,
#                              k_m: 0.0
# -logl: 2018.5977597576048, aic: 4053.1955195152095,
#                              k_llh: [1.05 1.  ],
#                              k_prior: [1. 1.],
#                              k_card: [1.],
#                              pr_tail: 0.0,
#                              p_rnd: 0.0,
#                              k_m: 0.0
# -logl: 2018.5977597576048, aic: 4053.1955195152095,
#                              k_llh: [1.   1.05],
#                              k_prior: [1. 1.],
#                              k_card: [1.],
#                              pr_tail: 0.0,
#                              p_rnd: 0.0,
#                              k_m: 0.0
# ...
